# %% [markdown]
# <a href="https://colab.research.google.com/github/Aravin423/ad_classes/blob/main/linear_regression_with_travel_destination.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
file_path = '/content/travel_destination_recommendation_dataset.csv'

# %%
import pandas as pd

file_path = '/content/travel_destination_recommendation_dataset.xlsx'

data = pd.read_excel(file_path)

# %%
data
# Out:
#        user_id  destination_id destination_name       country  user_age  \
# 0        15796            9366            Paris        France      44.4
# 1          861            1928           London            UK      45.0
# 2        38159            9541        Amsterdam   Netherlands      27.4
# 3        44733            3708      Los Angeles           USA      38.4
# 4        11285            3361   Rio de Janeiro        Brazil      53.6
# ...        ...             ...              ...           ...       ...
# 99995    10647            5466           Sydney     Australia      70.0
# 99996    13800            2623        Cape Town  South Africa      33.4
# 99997    47131            1556         Istanbul        Turkey      50.8
# 99998    49654            6001           Sydney     Australia      18.0
# 99999    12929            5763           Sydney     Australia      54.6
#
#        trip_duration_days  travel_budget_usd  popularity_score  \
# ...
