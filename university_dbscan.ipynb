# %% [markdown]
# <a href="https://colab.research.google.com/github/Aravin423/ad_classes/blob/main/university_dbscan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
file_path ="/content/Universities.csv"
df = pd.read_csv(file_path)

# %%
df
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
df.drop(['Top10', 'SFRatio'],axis=1,inplace=True)

# %%
df
# Out:
#             Univ   SAT  Accept  Expenses  GradRate
# 0          Brown  1310      22     22704        94
# 1        CalTech  1415      25     63575        81
# 2            CMU  1260      59     25026        72
# 3       Columbia  1310      24     31510        88
# 4        Cornell  1280      33     21864        90
# 5      Dartmouth  1340      23     32162        95
# 6           Duke  1315      30     31585        95
# 7     Georgetown  1255      24     20126        92
# 8        Harvard  1400      14     39525        97
# 9   JohnsHopkins  1305      44     58691        87
# 10           MIT  1380      30     34870        91
# 11  Northwestern  1260      39     28052        89
# 12     NotreDame  1255      42     15122        94
# 13     PennState  1081      54     10185        80
# 14     Princeton  1375      14     30220        95
# 15        Purdue  1005      90      9066        69
# 16      Stanford  1360      20     36450        93
# ...

# %%
array=df.values

# %%
array
# Out:
# array([['Brown', 1310, 22, 22704, 94],
#        ['CalTech', 1415, 25, 63575, 81],
#        ['CMU', 1260, 59, 25026, 72],
#        ['Columbia', 1310, 24, 31510, 88],
#        ['Cornell', 1280, 33, 21864, 90],
#        ['Dartmouth', 1340, 23, 32162, 95],
#        ['Duke', 1315, 30, 31585, 95],
#        ['Georgetown', 1255, 24, 20126, 92],
#        ['Harvard', 1400, 14, 39525, 97],
#        ['JohnsHopkins', 1305, 44, 58691, 87],
#        ['MIT', 1380, 30, 34870, 91],
#        ['Northwestern', 1260, 39, 28052, 89],
#        ['NotreDame', 1255, 42, 15122, 94],
#        ['PennState', 1081, 54, 10185, 80],
#        ['Princeton', 1375, 14, 30220, 95],
#        ['Purdue', 1005, 90, 9066, 69],
#        ['Stanford', 1360, 20, 36450, 93],
#        ['TexasA&M', 1075, 67, 8704, 67],
#        ['UCBerkeley', 1240, 40, 15140, 78],
#        ['UChicago', 1290, 50, 38380, 87],
#        ['UMichigan', 1180, 68, 15470, 85],
#        ['UPenn', 1285, 36, 27553, 90],
#        ['UVA', 1225, 44, 13349, 92],
# ...

# %%
stscaler = StandardScaler().fit(numerical_data)
X = stscaler.transform(numerical_data)

# %%
X
# Out:
# array([[ 0.41028362, -0.88986682, -0.33141256,  0.82030265],
#        [ 1.39925928, -0.73465749,  2.56038138, -0.64452351],
#        [-0.06065717,  1.02438157, -0.16712136, -1.65863393],
#        [ 0.41028362, -0.78639393,  0.29164871,  0.14422904],
#        [ 0.12771914, -0.32076595, -0.39084607,  0.36958691],
#        [ 0.69284809, -0.83813038,  0.33778044,  0.93298158],
#        [ 0.4573777 , -0.47597528,  0.29695528,  0.93298158],
#        [-0.10775125, -0.78639393, -0.51381683,  0.59494478],
#        [ 1.25797704, -1.30375836,  0.85874344,  1.15833946],
#        [ 0.36318954,  0.24833493,  2.21481798,  0.0315501 ],
#        [ 1.06960072, -0.47597528,  0.52938275,  0.48226584],
#        [-0.06065717, -0.01034729,  0.04698077,  0.25690797],
#        [-0.10775125,  0.14486204, -0.86787073,  0.82030265],
#        [-1.7466252 ,  0.76569936, -1.21718409, -0.75720245],
#        [ 1.02250664, -1.30375836,  0.20037583,  0.93298158],
# ...

# %%
dbscan = DBSCAN(eps=0.6, min_samples=8)
dbscan.fit(X)
# Out:
# DBSCAN(eps=0.6, min_samples=8)
