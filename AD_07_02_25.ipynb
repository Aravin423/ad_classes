# %% [markdown]
# <a href="https://colab.research.google.com/github/Aravin423/ad_classes/blob/main/AD_07_02_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

from google.colab import files
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
df = pd.read_csv(file_name)
# Out:
#      <input type="file" id="files-1273d920-e4ae-4f41-9999-485c47c901d2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1273d920-e4ae-4f41-9999-485c47c901d2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df[df.index.isin([56, 64])]
# Out:
#     Id                                              Model  Price  Age_08_04  \
# 56  57   TOYOTA Corolla 1.4 16V VVT I 5DR TERRA 4/5-Doors  15250         28
# 64  65  TOYOTA Corolla 1.4 16V VVT I 5DR TERRA COMFORT...  17950         27
#
#        KM  HP  Doors  Cylinders  Gears  Weight
# 56  43210  97      5          4      5    1110
# 64  32809  97      5          4      5    1110

# %%
Toyoto_Corrola1 = df.loc[df.index[[56,64]]].reset_index()

# %%
Toyoto_Corrola1 = df.drop(df.index[[56,64]],axis=0).reset_index()

# %%
Toyoto_Corrola1
# Out:
#       index    Id                                              Model  Price  \
# 0         0     1      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500
# 1         1     2      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750
# 2         2     3     ÊTOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950
# 3         3     4      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950
# 4         4     5        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750
# ...     ...   ...                                                ...    ...
# 1429   1431  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500
# 1430   1432  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845
# 1431   1433  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500
# 1432   1434  1441  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250
# 1433   1435  1442        TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors   6950
#
# ...

# %%
Toyoto_Corrola1.head()
# Out:
#    index  Id                                           Model  Price  \
# 0      0   1   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500
# 1      1   2   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750
# 2      2   3  ÊTOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950
# 3      3   4   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950
# 4      4   5     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750
#
#    Age_08_04     KM  HP  Doors  Cylinders  Gears  Weight
# 0         23  46986  90      3          4      5    1165
# 1         23  72937  90      3          4      5    1165
# 2         24  41711  90      3          4      5    1165
# 3         26  48000  90      3          4      5    1165
# 4         30  38500  90      3          4      5    1170

# %%
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

X = np.random.rand(100, 1)
Y = 2 * X + np.random.randn(100, 1)

X = sm.add_constant(X)

model = sm.OLS(Y, X).fit()

influence = model.get_influence()
cooks_distance = influence.cooks_distance[0]


fig = plt.figure(figsize=(10,4))
plt.stem(np.arange(len(cooks_distance)), np.round(cooks_distance, 3))

plt.xlabel('Row Index')
plt.ylabel('Cook\'s Distance')
plt.title('Cook\'s Distance Plot')
plt.show()

# %%
import matplotlib.pyplot as plt

from statsmodels.graphics.regressionplots import plot_leverage_resid2
fig = plt.figure(figsize=(10,4))
fig = plot_leverage_resid2(model)
plt.show()

# %%
'Id ~ Model + Price + Age_08_04 + KM + HP + Doors + Cylinders + Gears + Weight'
