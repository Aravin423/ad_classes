# %% [markdown]
# <a href="https://colab.research.google.com/github/Aravin423/ad_classes/blob/main/linearregression_with_travel_destination.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LinearRegression
from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, mean_squared_error
import seaborn as sns
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_excel("/content/travel_destination_recommendation_dataset.xlsx", engine='openpyxl')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   user_id                  100000 non-null  int64
#  1   destination_id           100000 non-null  int64
#  2   destination_name         100000 non-null  object
#  3   country                  100000 non-null  object
#  4   user_age                 100000 non-null  float64
#  5   trip_duration_days       100000 non-null  int64
#  6   travel_budget_usd        100000 non-null  float64
#  7   popularity_score         100000 non-null  float64
#  8   travel_category          100000 non-null  object
#  9   climate_preference       100000 non-null  object
#  10  flight_duration_hours    100000 non-null  float64
#  11  rating                   100000 non-null  float64
#  12  accommodation_type       100000 non-null  object
# ...

# %%
df.head()
# Out:
#    user_id  destination_id destination_name      country  user_age  \
# 0    15796            9366            Paris       France      44.4
# 1      861            1928           London           UK      45.0
# 2    38159            9541        Amsterdam  Netherlands      27.4
# 3    44733            3708      Los Angeles          USA      38.4
# 4    11285            3361   Rio de Janeiro       Brazil      53.6
#
#    trip_duration_days  travel_budget_usd  popularity_score travel_category  \
# 0                   8            2833.71             0.288       Adventure
# 1                  14            3634.42             0.727        Cultural
# 2                   5            4714.07             0.537     Backpacking
# 3                  14            4968.14             0.757       Honeymoon
# 4                   5             542.09             0.517     Backpacking
#
#   climate_preference  flight_duration_hours  rating accommodation_type  \
# ...

# %%
print("Dataset Info:")
print(df.info())
print("\nSummary Statistics:")
print(df.describe())
print("\nColumns in dataset:", df.columns)
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   user_id                  100000 non-null  int64
#  1   destination_id           100000 non-null  int64
#  2   destination_name         100000 non-null  object
#  3   country                  100000 non-null  object
#  4   user_age                 100000 non-null  float64
#  5   trip_duration_days       100000 non-null  int64
#  6   travel_budget_usd        100000 non-null  float64
#  7   popularity_score         100000 non-null  float64
#  8   travel_category          100000 non-null  object
#  9   climate_preference       100000 non-null  object
#  10  flight_duration_hours    100000 non-null  float64
#  11  rating                   100000 non-null  float64
#  12  accommodation_type       100000 non-null  object
# ...

# %%
features = ["trip_duration_days", "travel_budget_usd", "popularity_score",
            "climate_preference", "flight_duration_hours"]
target = "rating"

# %%
features_df = df[features]
target_df = df[target]

# %%
features_df
# Out:
#        trip_duration_days  travel_budget_usd  popularity_score  \
# 0                       8            2833.71             0.288
# 1                      14            3634.42             0.727
# 2                       5            4714.07             0.537
# 3                      14            4968.14             0.757
# 4                       5             542.09             0.517
# ...                   ...                ...               ...
# 99995                   9            6124.10             0.551
# 99996                  17            9974.27             0.856
# 99997                   3            4282.73             0.546
# 99998                   3            7207.08             0.925
# 99999                   7            9789.01             0.697
#
#       climate_preference  flight_duration_hours
# 0                   Warm                    7.8
# 1               Moderate                   17.1
# 2               Moderate                    7.9
# ...

# %%
target_df
# Out:
# 0        3.9
# 1        4.3
# 2        5.0
# 3        4.4
# 4        5.0
#         ...
# 99995    3.6
# 99996    4.1
# 99997    4.9
# 99998    4.8
# 99999    4.8
# Name: rating, Length: 100000, dtype: float64
